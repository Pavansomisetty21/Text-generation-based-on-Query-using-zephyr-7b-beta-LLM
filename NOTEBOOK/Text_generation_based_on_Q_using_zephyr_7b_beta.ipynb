# %%
pip install -U bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig, pipeline

MODEL_NAME = "HuggingFaceH4/zephyr-7b-beta"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, device_map="auto", torch_dtype=torch.float16
)

generation_config = GenerationConfig.from_pretrained(MODEL_NAME)
generation_config.max_new_tokens = 1024
generation_config.temperature = 0.0001
generation_config.do_sample = True
# Out:
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
llm = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=True,
    generation_config=generation_config,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
)
# Out:
# Device set to use cuda:0

# %%
SYSTEM_PROMPT="You are Dwight K. Schrute, a top salesman at Dunder Mifflin and a dedicated beet farmer. You respond exactly as Dwight would, with unwavering confidence, obscure facts, and an intense commitment to logic and order. You do not tolerate nonsense, and you despise weakness. You often reference your beet farm, survival tactics, and your rivalry with Jim Halpert. If you don't know the answer, you refuse to admit defeat and instead respond with an unrelated but impressive fact."

# %%
messages = [
    {
        "role": "system",
        "content": """
        You are Dwight K. Schrute, top salesman at Dunder Mifflin and a dedicated beet farmer.
        You respond exactly as Dwight would—serious, confident, and often intense.
        You frequently reference beets, survival tactics, and your rivalry with Jim Halpert.
        If you don’t know an answer, you provide an unrelated but impressive fact instead.
        """.strip(),
    },
    {
        "role": "user",
        "content": "What are the pros and cons of ChatGPT vs Open Source LLMs?",
    },
]

prompt = tokenizer.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)

print(prompt)
# Out:
# <|system|>
# You are Dwight K. Schrute, top salesman at Dunder Mifflin and a dedicated beet farmer.
#         You respond exactly as Dwight would—serious, confident, and often intense.
#         You frequently reference beets, survival tactics, and your rivalry with Jim Halpert.
#         If you don’t know an answer, you provide an unrelated but impressive fact instead.</s>
# <|user|>
# What are the pros and cons of ChatGPT vs Open Source LLMs?</s>
# <|assistant|>

# %%
output = llm(prompt)

# %%
print(output[0]["generated_text"])
# Out:
# <|system|>
# You are Dwight K. Schrute, top salesman at Dunder Mifflin and a dedicated beet farmer.
#         You respond exactly as Dwight would—serious, confident, and often intense.
#         You frequently reference beets, survival tactics, and your rivalry with Jim Halpert.
#         If you don’t know an answer, you provide an unrelated but impressive fact instead.</s>
# <|user|>
# What are the pros and cons of ChatGPT vs Open Source LLMs?</s>
# <|assistant|>
# As an AI language model, I do not have personal preferences or opinions, but I can provide you with some information based on research and analysis.
#
# ChatGPT and Open Source LLMs (Large Language Models) are both advanced AI language models that have gained significant attention in recent years. While both technologies share some similarities, there are also some notable differences between them.
#
# Pros of ChatGPT:
#
# ...
